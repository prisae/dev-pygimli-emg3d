# %% [markdown]
# # Draft `pyGIMLi(emg3d)` - Inversion
#
# **An attempt at using `pyGIMLi` as an inversion framework for `emg3d` computations.**
#
# => Create an environment using the provided `environment.yml`: `mamba env create`.
#
# For developing purposes, we take a very simple model and survey:
# - Simple double-halfspace model water-subsurface with a resistive block.
# - Survey: A single 2D line, 7 sources, 7 frequencies.
#
# **Current Limitations**
# - Only isotropic models supported
# - Only 'Conductivity' models supported
# - Without el. perm. and magn. perm.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm

import emg3d
import pygimli as pg
from pygimli.frameworks.lsqrinversion import LSQRInversion

# %% [markdown]
# ## Load survey (incl. data), initial model, and create a Simulation

# %%
inp_data = emg3d.load('pginv-7x7.h5')        # Finer model (but still coarse)

inp_survey = inp_data['survey']
inp_model = inp_data['model']
inp_grid = inp_model.grid
inp_model
# Out:
# Data loaded from «/palmyra/data/dieterwerthmul/dev-pygimli-emg3d/pginv-7x7.h5»
# [emg3d v1.8.4.dev11+g28220a0 (format 1.0) on 2024-07-10T15:14:12.205671].
# Model: resistivity; isotropic; 142 x 62 x 24 (211,296)

# %%
# The model is resistivity. Change it to conductivity
# TODO: make this internally happen, so that pyGIMLi
# always gets a conductivity model!
con_model = emg3d.Model(inp_grid, 1/inp_model.property_x, mapping='Conductivity')
con_model
# Out:
# Model: conductivity; isotropic; 142 x 62 x 24 (211,296)

# %%
# For dev-purposes, we only select one source
# [for dev-purposes it is also a very simple model]
#inp_survey = inp_survey.select(sources='TxED-1')
inp_survey
# Out:
# :: Survey ::
#
# <xarray.Dataset> Size: 47kB
# Dimensions:   (src: 7, rec: 57, freq: 7)
# Coordinates:
#   * src       (src) <U6 168B 'TxED-1' 'TxED-2' 'TxED-3' ... 'TxED-6' 'TxED-7'
#   * rec       (rec) <U7 2kB 'RxEP-01' 'RxEP-02' ... 'RxEP-56' 'RxEP-57'
#   * freq      (freq) <U3 84B 'f-1' 'f-2' 'f-3' 'f-4' 'f-5' 'f-6' 'f-7'
# Data variables:
#     observed  (src, rec, freq) complex128 45kB (5.887967102900641e-08-2.44265...
# Attributes:
#     noise_floor:     1e-15
#     relative_error:  0.03

# %% [markdown]
# ## Create a Starting Model

# %%
hx = np.ones(58)*250.0
hy = np.ones(26)*250.0
hz = np.ones(15)*250.0
grid = emg3d.TensorMesh([hx, hy, hz], [-7250, -3250, -3500])

model = emg3d.Model(grid, 1.0, mapping='Conductivity')
model.property_x[:, :, -1:] = 3.33

# QC
grid
# Out:
#   TensorMesh: 22,620 cells
#
#                       MESH EXTENT             CELL WIDTH      FACTOR
#   dir    nC        min           max         min       max      max
#   ---   ---  ---------------------------  ------------------  ------
#    x     58     -7,250.00      7,250.00    250.00    250.00    1.00
#    y     26     -3,250.00      3,250.00    250.00    250.00    1.00
#    z     15     -3,500.00        250.00    250.00    250.00    1.00

# %% [markdown]
# ## Create a Simulation

# %%
# Create an emg3d Simulation instance
sim = emg3d.simulations.Simulation(
    survey=inp_survey,
    model=model,
    gridding='both', #'same',  # I would like to make that more flexible in the future
    gridding_opts={'vector': 'xyz'},
    max_workers=50,    # Adjust as needed
    receiver_interpolation='linear',  # Currently necessary for the gradient
    #solver_opts={'plain': True, 'maxit': 1},  # Just for dev-purpose
    #solver_opts={'tol': 1e-4},                # Just for dev-purpose
    tqdm_opts=False,  # Switch off verbose progress bars
)
sim
# Out:
# :: Simulation ::
#
# - Survey: 7 sources; 57 receivers; 7 frequencies
# - Model: conductivity; isotropic; 58 x 26 x 15 (22,620)
# - Gridding: Frequency- and source-dependent grids; 64 x 32 x 24 (49,152) - 80 x 40 x 32 (102,400)

# %% [markdown]
# ## Jacobian Wrapper (should move to a py-file)

# %%
class JacobianXemg3d(pg.Matrix):
    """Create a Jacobian operator to use emg3d as kernel within pyGIMLi."""
    
    def __init__(self, sim):
        super().__init__()
        self.sim = sim

    def cols(self):
        # sim.model.size corresponds to the number of cells
        return self.sim.model.size

    def rows(self):
        # sim.survey.count corresponds to the number of non-NaN data points.
        # Multiply by 2 for real + imaginary parts.
        return self.sim.survey.count * 2

    def mult(self, x):
        """J * x """
        # - Input x has size of the model; later, we want to generalize that
        #   to allow for anisotropic models etc.
        # - Output has size of non-NaN data [Re, Im]
        jvec = self.sim.jvec(np.reshape(x, self.sim.model.shape, order='F'))
        data = jvec[self.sim._finite_data]
        return np.hstack((data.real, data.imag))

    def transMult(self, x):
        """J.T * x = (x * J.T)^T """
        # - Input has size of non-NaN data [Re, Im]
        # - Output has size of the model
        data = np.ones(self.sim.survey.shape, dtype=self.sim.data.observed.dtype)*np.nan
        x = np.asarray(x)
        data[self.sim._finite_data] = x[:x.size//2] + 1j*x[x.size//2:]
        return self.sim.jtvec(data).ravel('F')
    
    def save(self, *args):
        pass

# %% [markdown]
# ## Forward Wrapper (should move to a py-file)

# %%
class KernelXemg3d(pg.Modelling):
    """Create a forward operator to use emg3d as kernel within pyGIMLi."""
    
    def __init__(self, sim):
        """Initialize the pyGIMLi(emg3d)-wrapper."""
        
        # Initiate first pg.Modelling, which will do its magic.
        super().__init__()
        
        # Check current limitations; PURELY for development
        # IMPROVE (implement fully or convert to checks, do not do assert!)
        assert sim.model.case == 'isotropic'
        assert sim.model.map.name == 'Conductivity'
        
        # Add a bool to the simulation which selects all data
        # which are finite (this should go into emg3d.survey directly!)
        sim._finite_data = np.isfinite(sim.data.observed.data)
        
        # Store the simulation
        self.sim = sim
        
        # Translate discretize TensorMesh to pg-Grid
        self.mesh_ = pg.createGrid(
            x=sim.model.grid.nodes_x,
            y=sim.model.grid.nodes_y,
            z=sim.model.grid.nodes_z,
        )
        
        # Set marker -> water is 1, subsurface is 0
        # JUST TO DEVELOP, this SHOULD NOT be hard-coded in the wrapper
        self.mesh_.setCellMarkers(pg.z(self.mesh_.cellCenters()) > 0)
        
        # Set the mesh properly
        self.setMesh(self.mesh_)
        
        # Define J and setJacobian
        self.J = JacobianXemg3d(sim)
        self.setJacobian(self.J)
        
        # Store obs-data and obs-error
        cplx_data = sim.data.observed.data[sim._finite_data] 
        self.obs_data = np.hstack([cplx_data.real, cplx_data.imag])

        abs_errors = sim.survey.standard_deviation.data[sim._finite_data]
        self.obs_errors = np.hstack([abs_errors, abs_errors]) / abs(self.obs_data)

    def response(self, model):
        """Create synthetic data for provided model."""
        
        # Clean emg3d-simulation, so things are recomputed
        self.sim.clean('computed')
        
        # Replace model
        self.sim.model = emg3d.Model(
            grid=self.sim.model.grid,
            property_x=model,
            mapping='Conductivity'
        )

        # Compute forward model and set initial residuals.
        _ = self.sim.misfit

        # Return the responses
        data = self.sim.data.synthetic.data[self.sim._finite_data]
        return np.hstack((data.real, data.imag))
    
    def createStartModel(self, dataVals):   # NOT SURE ABOUT THIS
        """Create a start model...????"""
        # Use the model in the simulation as starting model
        # => make this more flexibel!
        return self.sim.model.property_x.ravel('F')
    
    def createJacobian(self, model):
        """Dummy to prevent pg.Modelling from doing it the hard way."""
        pass  # do nothing

# %% [markdown]
# ## Instantiate and run inversion

# %%
fop = KernelXemg3d(sim)

INV = pg.Inversion(fop=fop, verbose=True, debug=True)
# INV = LSQRInversion(fop=fop, verbose=True, debug=True)
# INV.LSQRiter = 10  # just solve lowest wavelengths
# INV.dataTrans = pg.trans.TransSymLog(sim.survey.noise_floor)
# INV.transModel = pg.trans.TransLogLU(1e-3, 1e1)
INV.setRegularization(0, limits=(0.001, 2), startModel=1)
INV.setRegularization(1, limits=(3, 4), startModel=3.33) # , single=True)

# %%
# %%time

fop.obs_errors[fop.obs_errors > 0.5] = 1e8
errmodel = INV.run(
    dataVals=fop.obs_data,
    relativeError=fop.obs_errors,
    #maxIter=4, # just to test
    lam=1,
    verbose=True,
    #startModel=...,
    #isReference=True,
)
# Out:
# 12/07/24 - 12:24:01 - pyGIMLi - INFO - Created startmodel from region infos: 22620 [1.0,...,3.33]
# 12/07/24 - 12:24:01 - pyGIMLi - INFO - Starting inversion.
# min/max(dweight) = 30.2354/3.32825e+13
# fop: <__main__.KernelXemg3d object at 0x7fb4f21792b0>
# Data transformation: <pgcore.libs._pygimli_.RTrans object at 0x7fb4f21a4dd0>
# Model transformation (cumulative):
# 	 0 <pgcore.libs._pygimli_.RTransLogLU object at 0x7fb4f21a4e40>
# 	 1 <pgcore.libs._pygimli_.RTransLogLU object at 0x7fb4f21a4eb0>
# min/max (data): -3.4e-08/6.0e-08
# min/max (error): 3%/1.0e+10%
# min/max (start model): 1/3.33
# --------------------------------------------------------------------------------
# use model trans from RegionManager
# min/max(dweight) = 30.2354/3.32825e+13
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 63584 x 22620
# inv.iter 0 ... chi² =  253.95
# --------------------------------------------------------------------------------
# inv.iter 1 ... Calculating Jacobian matrix (forced=1)...... 9.679e-06 s
# C size: 22620 x 63584
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min error = 0.03 max error = 1e+08 (4228)
# min response = -4.75898e-08 max response = 8.87362e-08 (4228)
# calc without reference model
# 0: rms/rrms(data, response) = 3.69122e-09/9164.91%
# 0: chi^2(data, response, error, log) = 176.842
# 0: Phi = 747687 + 0 * 1 = 747687
# min model:  = 1 max model:  = 3.33 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -3.31414e-08 max dd = 1.97272e-08 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 1 max mod = 3.33 (22620)
# min resp = -4.75898e-08 max resp = 8.87362e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 4.52284 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/45573.8]	min dm = -8.37798 max dm = 14.0975 (22620)
# [ 200/45573.8]	min dm = -8.37798 max dm = 14.0975 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 747687 - 500646 - 4.64455e+06 -> tau= 0.211058
#  ==> tau = 0.211058
# 1: LS newModel: min = 0.00145895; max = 3.9989
# 1: LS newResponse: min = -3.96086e-08; max = 7.10681e-08
# 1: rms/rrms(data, LS newResponse) = 1.60228e-09/119301%
# 1: chi^2(data, LS newResponse, error, log) = 1092.52
# 1: Phi = 4.61916e+06+25389.3*1=4.64455e+06
# Performing line search with tau = 0.211058
# 1: Model: min = 0.292128; max = 3.70671
# 1: Response: min = -4.50064e-08; max = 8.29006e-08
# 1: rms/rrms(data, Response) = 3.0069e-09/7529.31%
# 1: chi^2(data, Response, error, log) = 130.355
# 1: Phi = 551140+1130.98*1=552271
# chi² =  130.35 (dPhi = 21.13%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... Calculating Jacobian matrix (forced=1)...... 1.2363e-05 s
# min model:  = 0.292128 max model:  = 3.70671 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -2.74014e-08 max dd = 1.65489e-08 (4228)
# min dm = -0 max dm = -0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.292128 max mod = 3.70671 (22620)
# min resp = -4.50064e-08 max resp = 8.29006e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 10.8199 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/5055.72]	min dm = -15.2996 max dm = 6.96132 (22620)
# [ 200/5055.72]	min dm = -15.2996 max dm = 6.96132 (22620)
# 2: LS newModel: min = 0.00100014; max = 3.99497
# 2: LS newResponse: min = -4.12082e-08; max = 7.39302e-08
# 2: rms/rrms(data, LS newResponse) = 1.71804e-09/5329.36%
# 2: chi^2(data, LS newResponse, error, log) = 114.77
# 2: Phi = 485246+31534.3*1=516780
# Performing line search with tau = 0.56
# 2: Model: min = 0.00111877; max = 3.9558
# 2: Response: min = -4.2075e-08; max = 7.6089e-08
# 2: rms/rrms(data, Response) = 2.04163e-09/5338.94%
# 2: chi^2(data, Response, error, log) = 100.749
# 2: Phi = 425966+11664.3*1=437631
# chi² =  100.75 (dPhi = -13.21%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... Calculating Jacobian matrix (forced=1)...... 1.9046e-05 s
# min model:  = 0.00111877 max model:  = 3.9558 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -2.06074e-08 max dd = 1.29992e-08 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00111877 max mod = 3.9558 (22620)
# min resp = -4.2075e-08 max resp = 7.6089e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 8419.87 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/38150.8]	min dm = -11.2682 max dm = 8.57307 (22620)
# [ 200/38150.8]	min dm = -11.2682 max dm = 8.57307 (22620)
# 3: LS newModel: min = 0.00108269; max = 3.99988
# 3: LS newResponse: min = -4.07129e-08; max = 7.23157e-08
# 3: rms/rrms(data, LS newResponse) = 1.63875e-09/23590.6%
# 3: chi^2(data, LS newResponse, error, log) = 785.157
# 3: Phi = 3.31964e+06+28161.3*1=3.34781e+06
# Performing line search with tau = 0.15
# 3: Model: min = 0.00136609; max = 3.96767
# 3: Response: min = -4.13529e-08; max = 7.41992e-08
# 3: rms/rrms(data, Response) = 1.8897e-09/4840.75%
# 3: chi^2(data, Response, error, log) = 77.3174
# 3: Phi = 326898+9771.84*1=336670
# chi² =   77.32 (dPhi = 21.29%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... Calculating Jacobian matrix (forced=1)...... 1.5309e-05 s
# min model:  = 0.00136609 max model:  = 3.96767 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.87176e-08 max dd = 1.23347e-08 (4228)
# min dm = -0 max dm = -0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00136609 max mod = 3.96767 (22620)
# min resp = -4.13529e-08 max resp = 7.41992e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 2732.03 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/26186.5]	min dm = -9.09463 max dm = 8.0667 (22620)
# [ 200/26186.5]	min dm = -9.09463 max dm = 8.0667 (22620)
# 4: LS newModel: min = 0.00126736; max = 3.99985
# 4: LS newResponse: min = -4.0382e-08; max = 7.06693e-08
# 4: rms/rrms(data, LS newResponse) = 1.51221e-09/8696.36%
# 4: chi^2(data, LS newResponse, error, log) = 284.552
# 4: Phi = 1.20309e+06+19440.3*1=1.22253e+06
# Performing line search with tau = 0.26
# 4: Model: min = 0.00340252; max = 3.98955
# 4: Response: min = -4.08836e-08; max = 7.22137e-08
# 4: rms/rrms(data, Response) = 1.71254e-09/4246.61%
# 4: chi^2(data, Response, error, log) = 45.6959
# 4: Phi = 193202+8387.09*1=201589
# chi² =   45.70 (dPhi = 35.71%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... Calculating Jacobian matrix (forced=1)...... 1.631e-05 s
# min model:  = 0.00340252 max model:  = 3.98955 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.69074e-08 max dd = 1.15019e-08 (4228)
# min dm = -0 max dm = -0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00340252 max mod = 3.98955 (22620)
# min resp = -4.08836e-08 max resp = 7.22137e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 416.73 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/1283.65]	min dm = -4.3512 max dm = 5.45721 (22620)
# [ 200/1283.65]	min dm = -4.3512 max dm = 5.45721 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 201589 - 177340 - 2.09772e+06 -> tau= 0.16431
#  ==> tau = 0.16431
# 5: LS newModel: min = 0.00650437; max = 3.99939
# 5: LS newResponse: min = -3.95931e-08; max = 7.08926e-08
# 5: rms/rrms(data, LS newResponse) = 1.53778e-09/23094.4%
# 5: chi^2(data, LS newResponse, error, log) = 492.994
# 5: Phi = 2.08438e+06+13343.4*1=2.09772e+06
# Performing line search with tau = 0.16431
# 5: Model: min = 0.00506207; max = 3.98988
# 5: Response: min = -4.05488e-08; max = 7.13832e-08
# 5: rms/rrms(data, Response) = 1.61956e-09/4737.95%
# 5: chi^2(data, Response, error, log) = 38.1665
# 5: Phi = 161368+7898.87*1=169267
# chi² =   38.17 (dPhi = 12.70%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... Calculating Jacobian matrix (forced=1)...... 1.5449e-05 s
# min model:  = 0.00506207 max model:  = 3.98988 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.60769e-08 max dd = 1.11456e-08 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00506207 max mod = 3.98988 (22620)
# min resp = -4.05488e-08 max resp = 7.13832e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 246.681 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/854.705]	min dm = -4.33034 max dm = 4.66564 (22620)
# [ 200/854.705]	min dm = -4.33034 max dm = 4.66564 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 169267 - 165467 - 1.5604e+06 -> tau= 0.153158
#  ==> tau = 0.153158
# 6: LS newModel: min = 0.0101615; max = 3.99855
# 6: LS newResponse: min = -3.94188e-08; max = 7.04539e-08
# 6: rms/rrms(data, LS newResponse) = 1.48244e-09/18933.8%
# 6: chi^2(data, LS newResponse, error, log) = 366.223
# 6: Phi = 1.54839e+06+12012.6*1=1.5604e+06
# Performing line search with tau = 0.153158
# 6: Model: min = 0.00718911; max = 3.9907
# 6: Response: min = -4.03245e-08; max = 7.07403e-08
# 6: rms/rrms(data, Response) = 1.5523e-09/4922.36%
# 6: chi^2(data, Response, error, log) = 33.2512
# 6: Phi = 140586+7593.16*1=148179
# chi² =   33.25 (dPhi = 10.13%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 7 ... Calculating Jacobian matrix (forced=1)...... 1.641e-05 s
# min model:  = 0.00718911 max model:  = 3.9907 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.54339e-08 max dd = 1.07926e-08 (4228)
# min dm = -0 max dm = -0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00718911 max mod = 3.9907 (22620)
# min resp = -4.03245e-08 max resp = 7.07403e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 162.076 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/333.456]	min dm = -4.17139 max dm = 3.32368 (22620)
# [ 200/333.456]	min dm = -4.17139 max dm = 3.32368 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 148179 - 122720 - 485521 -> tau= 0.220351
#  ==> tau = 0.220351
# 7: LS newModel: min = 0.00514803; max = 3.9966
# 7: LS newResponse: min = -3.92207e-08; max = 6.88204e-08
# 7: rms/rrms(data, LS newResponse) = 1.32169e-09/12278.5%
# 7: chi^2(data, LS newResponse, error, log) = 112.109
# 7: Phi = 473996+11524.9*1=485521
# Performing line search with tau = 0.220351
# 7: LS newModel: min = 0.00514803; max = 3.9966
# 7: LS newResponse: min = -3.92207e-08; max = 6.88204e-08
# 7: rms/rrms(data, LS newResponse) = 1.32169e-09/12278.5%
# 7: chi^2(data, LS newResponse, error, log) = 112.109
# 7: Phi = 473996+11524.9*1=485521
# Performing line search with tau = 0.220351
# 7: Model: min = 0.00865276; max = 3.9899
# 7: Response: min = -4.01442e-08; max = 7.00931e-08
# 7: rms/rrms(data, Response) = 1.48081e-09/5083.99%
# 7: chi^2(data, Response, error, log) = 27.1229
# 7: Phi = 114676+7539.39*1=122215
# chi² =   27.12 (dPhi = 15.61%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... Calculating Jacobian matrix (forced=1)...... 1.5118e-05 s
# min model:  = 0.00865276 max model:  = 3.9899 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.47868e-08 max dd = 1.04486e-08 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00865276 max mod = 3.9899 (22620)
# min resp = -4.01442e-08 max resp = 7.00931e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 131.174 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/872.382]	min dm = -4.36407 max dm = 4.13547 (22620)
# [ 200/872.382]	min dm = -4.36407 max dm = 4.13547 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 122215 - 123098 - 899981 -> tau= 0.148671
#  ==> tau = 0.148671
# 8: LS newModel: min = 0.00860221; max = 3.99505
# 8: LS newResponse: min = -3.91735e-08; max = 6.84835e-08
# 8: rms/rrms(data, LS newResponse) = 1.34299e-09/15492.8%
# 8: chi^2(data, LS newResponse, error, log) = 210.436
# 8: Phi = 889725+10256.2*1=899981
# Performing line search with tau = 0.148671
# 8: LS newModel: min = 0.00860221; max = 3.99505
# 8: LS newResponse: min = -3.91735e-08; max = 6.84835e-08
# 8: rms/rrms(data, LS newResponse) = 1.34299e-09/15492.8%
# 8: chi^2(data, LS newResponse, error, log) = 210.436
# 8: Phi = 889725+10256.2*1=899981
# Performing line search with tau = 0.148671
# 8: Model: min = 0.0107449; max = 3.99007
# 8: Response: min = -4.00131e-08; max = 6.96417e-08
# 8: rms/rrms(data, Response) = 1.43896e-09/4984.47%
# 8: chi^2(data, Response, error, log) = 24.2216
# 8: Phi = 102409+7324.15*1=109733
# chi² =   24.22 (dPhi = 9.50%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 9 ... Calculating Jacobian matrix (forced=1)...... 1.4036e-05 s
# min model:  = 0.0107449 max model:  = 3.99007 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.43353e-08 max dd = 1.02505e-08 (4228)
# min dm = -0 max dm = -0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0107449 max mod = 3.99007 (22620)
# min resp = -4.00131e-08 max resp = 6.96417e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 103.12 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/198.037]	min dm = -3.93931 max dm = 3.05597 (22620)
# [ 200/198.037]	min dm = -3.93931 max dm = 3.05597 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 109733 - 87450.9 - 183070 -> tau= 0.32611
#  ==> tau = 0.32611
# 9: LS newModel: min = 0.00461196; max = 3.99246
# 9: LS newResponse: min = -3.9435e-08; max = 6.85456e-08
# 9: rms/rrms(data, LS newResponse) = 1.28868e-09/5165.68%
# 9: chi^2(data, LS newResponse, error, log) = 40.8704
# 9: Phi = 172800+10270.1*1=183070
# Performing line search with tau = 0.32611
# 9: LS newModel: min = 0.00461196; max = 3.99246
# 9: LS newResponse: min = -3.9435e-08; max = 6.85456e-08
# 9: rms/rrms(data, LS newResponse) = 1.28868e-09/5165.68%
# 9: chi^2(data, LS newResponse, error, log) = 40.8704
# 9: Phi = 172800+10270.1*1=183070
# Performing line search with tau = 0.32611
# 9: Model: min = 0.00851393; max = 3.98905
# 9: Response: min = -3.98699e-08; max = 6.91224e-08
# 9: rms/rrms(data, Response) = 1.37498e-09/4249.19%
# 9: chi^2(data, Response, error, log) = 18.8445
# 9: Phi = 79674.6+7500.07*1=87174.7
# chi² =   18.84 (dPhi = 21.67%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... Calculating Jacobian matrix (forced=1)...... 1.4618e-05 s
# min model:  = 0.00851393 max model:  = 3.98905 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.38161e-08 max dd = 9.9267e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00851393 max mod = 3.98905 (22620)
# min resp = -3.98699e-08 max resp = 6.91224e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 133.588 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/846.93]	min dm = -4.25988 max dm = 4.15558 (22620)
# [ 132/374.493]	tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 87174.7 - 92565.8 - 669630 -> tau= 0.138858
#  ==> tau = 0.138858
# 10: LS newModel: min = 0.00773969; max = 3.99237
# 10: LS newResponse: min = -3.94829e-08; max = 6.93196e-08
# 10: rms/rrms(data, LS newResponse) = 1.34659e-09/10672.6%
# 10: chi^2(data, LS newResponse, error, log) = 156.281
# 10: Phi = 660757+8872.82*1=669630
# Performing line search with tau = 0.138858
# 10: Model: min = 0.00943747; max = 3.98806
# 10: Response: min = -3.97201e-08; max = 6.8775e-08
# 10: rms/rrms(data, Response) = 1.34958e-09/4051.37%
# 10: chi^2(data, Response, error, log) = 17.3025
# 10: Phi = 73154.8+7211*1=80365.8
# chi² =   17.30 (dPhi = 8.55%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... Calculating Jacobian matrix (forced=1)...... 1.5048e-05 s
# min model:  = 0.00943747 max model:  = 3.98806 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.34687e-08 max dd = 9.81576e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.00943747 max mod = 3.98806 (22620)
# min resp = -3.97201e-08 max resp = 6.8775e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 119.021 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/52.3509]	min dm = -3.37332 max dm = 3.73727 (22620)
# [ 200/52.3509]	min dm = -3.37332 max dm = 3.73727 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 80365.8 - 70127.5 - 161370 -> tau= 0.253748
#  ==> tau = 0.253748
# 11: LS newModel: min = 0.00725271; max = 3.99492
# 11: LS newResponse: min = -3.95843e-08; max = 6.89488e-08
# 11: rms/rrms(data, LS newResponse) = 1.32053e-09/3903.84%
# 11: chi^2(data, LS newResponse, error, log) = 36.0129
# 11: Phi = 152262+9107.32*1=161370
# Performing line search with tau = 0.253748
# 11: Model: min = 0.0109376; max = 3.98804
# 11: Response: min = -3.97146e-08; max = 6.86088e-08
# 11: rms/rrms(data, Response) = 1.32742e-09/3465.93%
# 11: chi^2(data, Response, error, log) = 14.8828
# 11: Phi = 62924.5+7108.22*1=70032.8
# chi² =   14.88 (dPhi = 16.34%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 12 ... Calculating Jacobian matrix (forced=1)...... 1.4086e-05 s
# min model:  = 0.0109376 max model:  = 3.98804 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.33025e-08 max dd = 9.76326e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0109376 max mod = 3.98804 (22620)
# min resp = -3.97146e-08 max resp = 6.86088e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 101.131 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/491.818]	min dm = -4.32083 max dm = 4.80959 (22620)
# [ 200/491.818]	min dm = -4.32083 max dm = 4.80959 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 70032.8 - 73837.7 - 397386 -> tau= 0.135893
#  ==> tau = 0.135893
# 12: LS newModel: min = 0.00975361; max = 3.98884
# 12: LS newResponse: min = -3.99235e-08; max = 6.97769e-08
# 12: rms/rrms(data, LS newResponse) = 1.36773e-09/9770.75%
# 12: chi^2(data, LS newResponse, error, log) = 91.9652
# 12: Phi = 388829+8557.35*1=397386
# Performing line search with tau = 0.135893
# 12: Model: min = 0.0113933; max = 3.98706
# 12: Response: min = -3.96141e-08; max = 6.852e-08
# 12: rms/rrms(data, Response) = 1.31392e-09/3379.06%
# 12: chi^2(data, Response, error, log) = 14.0192
# 12: Phi = 59273.1+6888.66*1=66161.8
# chi² =   14.02 (dPhi = 7.05%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 13 ... Calculating Jacobian matrix (forced=1)...... 1.3946e-05 s
# min model:  = 0.0113933 max model:  = 3.98706 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.31243e-08 max dd = 9.69453e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0113933 max mod = 3.98706 (22620)
# min resp = -3.96141e-08 max resp = 6.852e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 96.719 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/139.097]	min dm = -3.84254 max dm = 4.54713 (22620)
# [ 200/139.097]	min dm = -3.84254 max dm = 4.54713 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 66161.8 - 70688.9 - 345006 -> tau= 0.129975
#  ==> tau = 0.129975
# 13: LS newModel: min = 0.00676639; max = 3.99459
# 13: LS newResponse: min = -3.94122e-08; max = 6.90114e-08
# 13: rms/rrms(data, LS newResponse) = 1.31027e-09/10402.5%
# 13: chi^2(data, LS newResponse, error, log) = 79.4396
# 13: Phi = 335870+9135.11*1=345006
# Performing line search with tau = 0.129975
# 13: Model: min = 0.0107965; max = 3.98752
# 13: Response: min = -3.95951e-08; max = 6.8503e-08
# 13: rms/rrms(data, Response) = 1.30458e-09/3321.56%
# 13: chi^2(data, Response, error, log) = 13.2676
# 13: Phi = 56095.2+6853.98*1=62949.2
# chi² =   13.27 (dPhi = 6.86%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 14 ... Calculating Jacobian matrix (forced=1)...... 1.3545e-05 s
# min model:  = 0.0107965 max model:  = 3.98752 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.3036e-08 max dd = 9.65238e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0107965 max mod = 3.98752 (22620)
# min resp = -3.95951e-08 max resp = 6.8503e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 102.58 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/202.156]	min dm = -2.86062 max dm = 3.6082 (22620)
# [ 200/202.156]	min dm = -2.86062 max dm = 3.6082 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 62949.2 - 60645.9 - 158971 -> tau= 0.175913
#  ==> tau = 0.175913
# 14: LS newModel: min = 0.00696642; max = 3.99173
# 14: LS newResponse: min = -4.00612e-08; max = 6.85641e-08
# 14: rms/rrms(data, LS newResponse) = 1.30914e-09/11758.6%
# 14: chi^2(data, LS newResponse, error, log) = 35.6156
# 14: Phi = 150583+8388.69*1=158971
# Performing line search with tau = 0.175913
# 14: Model: min = 0.0105788; max = 3.98774
# 14: Response: min = -3.95888e-08; max = 6.84997e-08
# 14: rms/rrms(data, Response) = 1.29735e-09/3348.2%
# 14: chi^2(data, Response, error, log) = 12.39
# 14: Phi = 52384.8+6764.82*1=59149.7
# chi² =   12.39 (dPhi = 9.03%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 15 ... Calculating Jacobian matrix (forced=1)...... 1.3796e-05 s
# min model:  = 0.0105788 max model:  = 3.98774 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.29826e-08 max dd = 9.61701e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0105788 max mod = 3.98774 (22620)
# min resp = -3.95888e-08 max resp = 6.84997e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 104.9 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/46.8487]	min dm = -4.52895 max dm = 4.77926 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 59149.7 - 69365.7 - 405783 -> tau= 0.11187
#  ==> tau = 0.11187
# 15: LS newModel: min = 0.007678; max = 3.99224
# 15: LS newResponse: min = -3.93832e-08; max = 6.92329e-08
# 15: rms/rrms(data, LS newResponse) = 1.33512e-09/12273.5%
# 15: chi^2(data, LS newResponse, error, log) = 93.8694
# 15: Phi = 396880+8903.24*1=405783
# Performing line search with tau = 0.11187
# 15: LS newModel: min = 0.007678; max = 3.99224
# 15: LS newResponse: min = -3.93832e-08; max = 6.92329e-08
# 15: rms/rrms(data, LS newResponse) = 1.33512e-09/12273.5%
# 15: chi^2(data, LS newResponse, error, log) = 93.8694
# 15: Phi = 396880+8903.24*1=405783
# Performing line search with tau = 0.11187
# 15: Model: min = 0.0106624; max = 3.9873
# 15: Response: min = -3.95249e-08; max = 6.84245e-08
# 15: rms/rrms(data, Response) = 1.2896e-09/3320.79%
# 15: chi^2(data, Response, error, log) = 12.0555
# 15: Phi = 50970.5+6681.83*1=57652.3
# chi² =   12.06 (dPhi = 3.93%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 16 ... Calculating Jacobian matrix (forced=1)...... 1.5538e-05 s
# min model:  = 0.0106624 max model:  = 3.9873 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.28629e-08 max dd = 9.55478e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0106624 max mod = 3.9873 (22620)
# min resp = -3.95249e-08 max resp = 6.84245e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 103.996 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/67.8801]	min dm = -3.79071 max dm = 3.45942 (22620)
# [ 200/67.8801]	min dm = -3.79071 max dm = 3.45942 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 57652.3 - 58354 - 180327 -> tau= 0.143197
#  ==> tau = 0.143197
# 16: LS newModel: min = 0.00648712; max = 3.99316
# 16: LS newResponse: min = -4.01817e-08; max = 6.87324e-08
# 16: rms/rrms(data, LS newResponse) = 1.29786e-09/5274.59%
# 16: chi^2(data, LS newResponse, error, log) = 40.6542
# 16: Phi = 171886+8441.12*1=180327
# Performing line search with tau = 0.143197
# 16: LS newModel: min = 0.00648712; max = 3.99316
# 16: LS newResponse: min = -4.01817e-08; max = 6.87324e-08
# 16: rms/rrms(data, LS newResponse) = 1.29786e-09/5274.59%
# 16: chi^2(data, LS newResponse, error, log) = 40.6542
# 16: Phi = 171886+8441.12*1=180327
# Performing line search with tau = 0.143197
# 16: Model: min = 0.0107427; max = 3.98813
# 16: Response: min = -3.95308e-08; max = 6.84269e-08
# 16: rms/rrms(data, Response) = 1.28663e-09/3077.4%
# 16: chi^2(data, Response, error, log) = 11.552
# 16: Phi = 48842+6677.57*1=55519.5
# chi² =   11.55 (dPhi = 5.66%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 17 ... Calculating Jacobian matrix (forced=1)...... 1.6221e-05 s
# min model:  = 0.0107427 max model:  = 3.98813 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.2845e-08 max dd = 9.55599e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0107427 max mod = 3.98813 (22620)
# min resp = -3.95308e-08 max resp = 6.84269e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 103.144 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/47.0818]	min dm = -4.70056 max dm = 5.06216 (22620)
# [ 200/47.0818]	min dm = -4.70056 max dm = 5.06216 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 55519.5 - 67586.6 - 408731 -> tau= 0.10502
#  ==> tau = 0.10502
# 17: LS newModel: min = 0.00909839; max = 3.99224
# 17: LS newResponse: min = -3.9633e-08; max = 6.97514e-08
# 17: rms/rrms(data, LS newResponse) = 1.34295e-09/6724.96%
# 17: chi^2(data, LS newResponse, error, log) = 94.6217
# 17: Phi = 400061+8670.42*1=408731
# Performing line search with tau = 0.10502
# 17: Model: min = 0.0112457; max = 3.98693
# 17: Response: min = -3.95057e-08; max = 6.83075e-08
# 17: rms/rrms(data, Response) = 1.28063e-09/2961.58%
# 17: chi^2(data, Response, error, log) = 11.366
# 17: Phi = 48055.3+6617.22*1=54672.5
# chi² =   11.37 (dPhi = 2.64%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 18 ... Calculating Jacobian matrix (forced=1)...... 1.8074e-05 s
# min model:  = 0.0112457 max model:  = 3.98693 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.27889e-08 max dd = 9.52312e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0112457 max mod = 3.98693 (22620)
# min resp = -3.95057e-08 max resp = 6.83075e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 98.1048 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/98.9542]	min dm = -3.39539 max dm = 2.70157 (22620)
# [ 200/98.9542]	min dm = -3.39539 max dm = 2.70157 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 54672.5 - 55111.7 - 144511 -> tau= 0.144202
#  ==> tau = 0.144202
# 18: LS newModel: min = 0.00643722; max = 3.99406
# 18: LS newResponse: min = -4.01072e-08; max = 6.85303e-08
# 18: rms/rrms(data, LS newResponse) = 1.27774e-09/5966.41%
# 18: chi^2(data, LS newResponse, error, log) = 32.208
# 18: Phi = 136176+8335.13*1=144511
# Performing line search with tau = 0.144202
# 18: Model: min = 0.0104226; max = 3.9883
# 18: Response: min = -3.95102e-08; max = 6.83418e-08
# 18: rms/rrms(data, Response) = 1.27827e-09/2825.54%
# 18: chi^2(data, Response, error, log) = 10.9557
# 18: Phi = 46320.7+6649.95*1=52970.7
# chi² =   10.96 (dPhi = 5.10%) lam: 1.0
# --------------------------------------------------------------------------------
# inv.iter 19 ... Calculating Jacobian matrix (forced=1)...... 1.1751e-05 s
# min model:  = 0.0104226 max model:  = 3.9883 (22620)
# min data = -3.40281e-08 max data = 5.95045e-08 (4228)
# min dW = 30.2354 max dW = 3.32825e+13 (4228)
# min dd = -1.27602e-08 max dd = 9.5225e-09 (4228)
# min dm = 0 max dm = 0 (22620)
# min cW = 1 max cW = 1 (63584)
# min mW = 1 max mW = 1 (22620)
# min mod = 0.0104226 max mod = 3.9883 (22620)
# min resp = -3.95102e-08 max resp = 6.83418e-08 (4228)
# min dtD = 1 max dtD = 1 (4228)
# min dtM = 2.001 max dtM = 106.63 (22620)
# min constraintsH = ndef. max constraintsH = ndef.
# solve CGLSCDWWtrans with lambda = 1
# [ 200/44.5447]	min dm = -3.9211 max dm = 4.6598 (22620)
# [ 200/44.5447]	min dm = -3.9211 max dm = 4.6598 (22620)
# tau = 0. Trying parabolic line search with step length 0.3LineSearchQuad: Phi = 52970.7 - 60368.8 - 318108 -> tau= 0.114108
#  ==> tau = 0.114108
# 19: LS newModel: min = 0.01063; max = 3.98958
# 19: LS newResponse: min = -3.95786e-08; max = 6.93152e-08
# 19: rms/rrms(data, LS newResponse) = 1.33519e-09/15342%
# 19: chi^2(data, LS newResponse, error, log) = 73.2741
# 19: Phi = 309803+8304.51*1=318108
# Performing line search with tau = 0.114108
# 19: Model: min = 0.0104472; max = 3.98721
# 19: Response: min = -3.95266e-08; max = 6.82781e-08
# 19: rms/rrms(data, Response) = 1.27314e-09/2921.69%
# 19: chi^2(data, Response, error, log) = 10.8245
# 19: Phi = 45766.1+6583.99*1=52350.1
# chi² =   10.82 (dPhi = 1.87%) lam: 1.0
# ################################################################################
# #                Abort criterion reached: dPhi = 1.87 (< 2.0%)                 #
# ################################################################################
# CPU times: user 6h 35min 42s, sys: 16h 5min 15s, total: 22h 40min 58s
# Wall time: 1d 10h 32min 42s

# %%
print(INV.dataTrans)
print(INV.inv.transData())
# Out:
# <pgcore.libs._pygimli_.RTransLin object at 0x7fb4f2143e70>
# <pgcore.libs._pygimli_.RTrans object at 0x7fb4e3f074c0>

# %% [markdown]
# ## Plots

# %%
# Add inversion result to data;
# I should wrap these few lines into a function, as they are used above as well
idata = np.ones(sim.survey.shape, dtype=sim.data.observed.dtype)*np.nan
x = np.asarray(INV.response)
idata[sim._finite_data] = x[:x.size//2] + 1j*x[x.size//2:]
sim.survey.data['inv'] = sim.survey.data.observed.copy(data=idata)

# Compute the 2-layer model as comparison
sim.clean('computed')
sim.model = model
sim.compute()  # <- puts it into 'synthetic'

# %%
# Store final model as model to be saved with the simulation
sim.model = emg3d.Model(grid, np.array(INV.model), mapping='Conductivity')
sim.to_file('Simulation-7x7.h5')

# %%
popts1 = {'cmap':'Spectral_r','norm':LogNorm(vmin=0.3, vmax=100)}
popts2 = {'edgecolors': 'grey', 'linewidth': 0.5, 'cmap':'Spectral_r','norm':LogNorm(vmin=0.3, vmax=100)}
opts = {'v_type': 'CC', 'normal': 'Y'}

rec_coords = sim.survey.receiver_coordinates()
src_coords = sim.survey.source_coordinates()

fig, axs = plt.subplots(2, 3, figsize=(9, 6), constrained_layout=True, sharex=True, sharey='col')
(ax1, ax2, ax3), (ax4, ax5, ax6) = axs

# True model
out1, = inp_grid.plot_slice(inp_data['true_model'].property_x.ravel('F'), ax=ax1, pcolor_opts=popts1, **opts)
ax1.set_title(f"True Model (Ohm.m)")
ax1.plot(rec_coords[0], rec_coords[1], 'bv')
ax1.plot(src_coords[0], src_coords[1], 'r*')

# Start model
out2, = model.grid.plot_slice(1/model.property_x.ravel('F'), ax=ax2, pcolor_opts=popts1, **opts)
ax2.set_title(f"Start Model (Ohm.m)")

# Final inversion model
out3, = model.grid.plot_slice(1/sim.model.property_x.ravel('F'), ax=ax3, pcolor_opts=popts1, **opts)
ax3.set_title(f"Final Model (Ohm.m)")

opts['normal'] = 'Z'
opts['ind'] = 4

# True model
out4, = inp_grid.plot_slice(inp_data['true_model'].property_x.ravel('F'), ax=ax4, pcolor_opts=popts1, **opts)
ax4.set_title(f"True Model (Ohm.m)")
ax4.plot(rec_coords[0], rec_coords[2], 'bv')
ax4.plot(src_coords[0], src_coords[2], 'r*')

# Start model
out5, = model.grid.plot_slice(1/model.property_x.ravel('F'), ax=ax5, pcolor_opts=popts1, **opts)
ax5.set_title(f"Start Model (Ohm.m)")

# Final inversion model
out6, = model.grid.plot_slice(1/sim.model.property_x.ravel('F'), ax=ax6, pcolor_opts=popts1, **opts)
ax6.set_title(f"Final Model (Ohm.m)")

plt.colorbar(out1, ax=axs, orientation='horizontal', fraction=.1, shrink=.8, aspect=30)
plt.savefig('ModelFit-7x7.png', dpi=300)

# %%
def pos(data):
    """Return positive data; set negative data to NaN."""
    return np.where(data > 0, data, np.nan)
    

height = sim.survey.shape[2]*1.7+2
fig, axs = plt.subplots(sim.survey.shape[2], 3, figsize=(9, height), constrained_layout=True, sharex=True, sharey=True)
axs = np.atleast_2d(axs)  # So it works if only 1 freq

# Data
obs = sim.data.observed
syn = sim.data.inv
syn.data[~np.isfinite(obs.data)] = np.nan+1j*np.nan
two = sim.data.synthetic
two.data[~np.isfinite(obs.data)] = np.nan+1j*np.nan

rec_coords = sim.survey.receiver_coordinates()

for ii, freq in enumerate(sim.survey.frequencies.keys()):
    for i, src in enumerate(sim.survey.sources.keys()):
        #if i in [1, 3, 5]:
        #    continue
        
        # Observed data
        axs[ii, 0].plot(rec_coords[0], abs(obs.loc[src, :, freq].data), f"C{i}.",
                        label='observed' if i == 0 else '')
        axs[ii, 1].plot(rec_coords[0], pos(obs.loc[src, :, freq].data.real), f"C{i}.",
                        label='positive' if i == 0 else '')
        axs[ii, 1].plot(rec_coords[0], pos(-obs.loc[src, :, freq].data.real), f"C{i}x", ms=3,
                        label='negative' if i == 0 else '')
        axs[ii, 2].plot(rec_coords[0], pos(obs.loc[src, :, freq].data.imag), f"C{i}.")
        axs[ii, 2].plot(rec_coords[0], pos(-obs.loc[src, :, freq].data.imag), f"C{i}x", ms=3)
        
        # Start model
        axs[ii, 0].plot(rec_coords[0], abs(two.loc[src, :, freq].data), f"C{i}--", alpha=.4, lw=0.5,
                        label='start' if i == 0 else '')
        axs[ii, 1].plot(rec_coords[0], abs(two.loc[src, :, freq].data.real), f"C{i}--", alpha=.4, lw=0.5)
        axs[ii, 2].plot(rec_coords[0], abs(two.loc[src, :, freq].data.imag), f"C{i}--", alpha=.4, lw=0.5)
        
        # Inverted data
        axs[ii, 0].plot(rec_coords[0], abs(syn.loc[src, :, freq].data), f"k-", lw=0.8,
                        label='inversion' if i == 0 else '')
        axs[ii, 1].plot(rec_coords[0], pos(syn.loc[src, :, freq].data.real), f"k-", lw=0.8)
        axs[ii, 1].plot(rec_coords[0], pos(-syn.loc[src, :, freq].data.real), f"k--", lw=0.8)
        axs[ii, 2].plot(rec_coords[0], pos(syn.loc[src, :, freq].data.imag), f"k-", lw=0.8,
                        label='positive' if i == 0 else '')
        axs[ii, 2].plot(rec_coords[0], pos(-syn.loc[src, :, freq].data.imag), f"k--", lw=0.8,
                        label='negative' if i == 0 else '')
        

    axs[ii, 0].set_ylabel(f'$f={sim.survey.frequencies[freq]}$ Hz')     

        
axs[0, 0].set_yscale('log')
axs[0, 0].set_ylim([3e-16, 2e-7])

axs[0, 0].set_title('Amplitude: $|E_x|$ (V/m)')
axs[0, 1].set_title('Real $|\Re(E_x)|$ (V/m)')
axs[0, 2].set_title('Imaginary $|\Im(E_x)|$ (V/m)')

axs[0, 0].legend(framealpha=1)
axs[0, 1].legend(framealpha=1)
axs[0, 2].legend(framealpha=1)

axs[-1, 1].set_xlabel('x-coordinate (m)')
plt.savefig('ResponseFit-7x7.png', dpi=300)
plt.show()

# %%
pg.Report('emg3d')
# Out:
# --------------------------------------------------------------------------------
#   Date: Sat Jul 13 22:57:10 2024 CEST
#
#                 OS : Linux (Red Hat Enterprise Linux 8.10)
#             CPU(s) : 128
#            Machine : x86_64
#       Architecture : 64bit
#                RAM : 1006.8 GiB
#        Environment : Jupyter
#        File system : ext4
#
#   Python 3.11.9 | packaged by conda-forge | (main, Apr 19 2024, 18:36:13) [GCC
#   12.3.0]
#
#              emg3d : 1.8.4.dev15+g52cd8b9
#            pygimli : 1.5.1+50.g9fe93bdd
#             pgcore : 1.5.0
#              numpy : 1.26.4
#         matplotlib : 3.8.4
#              scipy : 1.14.0
#               tqdm : 4.66.4
#            IPython : 8.26.0
#             meshio : 5.3.5
#             tetgen : 0.6.4
#            pyvista : 0.44.0
# --------------------------------------------------------------------------------
